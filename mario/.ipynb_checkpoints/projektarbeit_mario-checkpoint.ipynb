# %%
import math

# %%
import findspark
findspark.init()
import pyspark # only run after findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
df = spark.sql('''select 'spark' as hello ''')
df.show()
# Out:
# +-----+
# |hello|
# +-----+
# |spark|
# +-----+

# %%
df = spark.read.options(inferSchema='True', header=True).csv("/run/media/mario/shared_partition/WS2022-2023/Big Data and Advanced Database System Concepts/cdc_download_2022-12-07_16-46_temperatur/data/data_OBS_DEU_PT10M_T2M.csv")
df.printSchema()
# Out:
# [Stage 28:>                                                         (0 + 8) / 8]
# root
#  |-- Produkt_Code: string (nullable = true)
#  |-- SDO_ID: integer (nullable = true)
#  |-- Zeitstempel: timestamp (nullable = true)
#  |-- Wert: double (nullable = true)
#  |-- Qualitaet_Byte: integer (nullable = true)
#  |-- Qualitaet_Niveau: integer (nullable = true)

# %%
df.show()
# Out:
# +-----------------+------+-------------------+----+--------------+----------------+
# |     Produkt_Code|SDO_ID|        Zeitstempel|Wert|Qualitaet_Byte|Qualitaet_Niveau|
# +-----------------+------+-------------------+----+--------------+----------------+
# |OBS_DEU_PT10M_T2M|  2680|2010-01-01 00:00:00| 3.0|           111|               3|
# |OBS_DEU_PT10M_T2M|  2680|2010-01-01 00:10:00| 3.0|           111|               3|
# |OBS_DEU_PT10M_T2M|  2680|2010-01-01 00:20:00| 2.9|           111|               3|
# |OBS_DEU_PT10M_T2M|  2680|2010-01-01 00:30:00| 2.9|           111|               3|
# |OBS_DEU_PT10M_T2M|  2680|2010-01-01 00:40:00| 2.9|           111|               3|
# |OBS_DEU_PT10M_T2M|  2680|2010-01-01 00:50:00| 2.8|           111|               3|
# |OBS_DEU_PT10M_T2M|  2680|2010-01-01 01:00:00| 2.7|           111|               3|
# |OBS_DEU_PT10M_T2M|  2680|2010-01-01 01:10:00| 2.5|           111|               3|
# ...

# %%
x = df.groupBy("Wert").count()

# %%
x.count()
# Out:
# 623

# %%
x.show(1000)
# Out:
# +-----+-----+
# | Wert|count|
# +-----+-----+
# |-12.3|  180|
# | 13.4| 4636|
# | 14.9| 4270|
# | 15.5| 4056|
# | 26.7|  543|
# | 15.4| 4015|
# | -1.2| 3351|
# | -5.5|  978|
# |  2.4| 4989|
# |  8.0| 4948|
# | 10.2| 4907|
# | 15.7| 3967|
# | 25.1|  882|
# | -4.6| 1289|
# | -6.9|  673|
# |-14.5|   99|
# | 18.3| 3009|
# | 24.7|  963|
# | 32.3|   88|
# |  0.0| 4707|
# |-17.8|   29|
# | 17.9| 3092|
# | 26.4|  597|
# |-11.6|  181|
# |  5.4| 5317|
# | 11.4| 4835|
# | 16.6| 3633|
# | 23.8| 1175|
# |  7.0| 4909|
# | 15.9| 3858|
# | 24.9|  917|
# |-21.9|    4|
# | -6.8|  755|
# |-19.3|   26|
# | 11.5| 4780|
# |  3.5| 5003|
# | 31.7|  110|
# | -1.4| 3221|
# | -5.0| 1260|
# | -9.2|  400|
# |-19.8|   23|
# |  6.1| 5252|
# |  9.5| 4766|
# |-18.0|   51|
# | 11.6| 4669|
# | -1.3| 3387|
# | -1.7| 2850|
# |  7.7| 5076|
# | 31.1|  143|
# |-20.7|   17|
# | 23.9| 1151|
# | 26.6|  598|
# |  0.2| 4964|
# |-16.9|   59|
# | 17.3| 3381|
# | 25.2|  819|
# | 31.6|  119|
# |  6.6| 4806|
# | 20.5| 2106|
# ...
